# %%
import requests
from bs4 import BeautifulSoup

# %%
r=requests.get("https://www.century21.com/real-estate/san-francisco-ca/LCCASANFRANCISCO/")
c=r.content

# %%
soup=BeautifulSoup(c,"html.parser")
# print(soup.prettify())

# %%
all=soup.find_all("div", {"class":"logo"})

# %%
all
# Out:
# [<div class="logo"><a data-usagetrack-click="Logo" href="/">Home</a></div>]

# %%
all=soup.find_all("div", {"class":"filters-container"})

# %%
all
# Out:
# []

# %%
all=soup.find_all("div", {"class":"full-width-container"})

# %%
all
# Out:
# []

# %%
all=soup.find_all("div", {"class":"property-actions"})

# %%
all
# Out:
# [<div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>,
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>]

# %%
type(all)
# Out:
# bs4.element.ResultSet

# %%
len(all)
# Out:
# 20

# %%
all[0]
# Out:
# <div class="property-actions">
# <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
# <button class="action-favorite" title="Set as Favorite" type="button"></button>
# </div>

# %%
all1=soup.find_all("div", {"class":"infinite-container"})

# %%
all1
# Out:
# lass="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/240-morningside-drive-san-francisco-ca-94132-CBR51633001">
#
#
#                 $2,200,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>4</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>2,996</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="240 Morningside Drive">
#                 240 Morningside Drive
#              </div>
#  <div class="property-city">
#              San Francisco CA 94132
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Coldwell Banker San Francisco Lakeside
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>
#  <div class="infinite-item property-card clearfix property-card-CBR51632374" data-brand-cd="CBR" data-id="CBR51632374" data-latitude="37.77393" data-link="/property/300-berry-street-unit-1009-san-francisco-ca-94158-CBR51632374" data-listing-id="" data-longitude="-122.396241" data-mls="508114" data-source-id="4DA4E382-ECBF-4DA6-9523-11665B3A778B" data-zip="94158">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://cb.azureedge.net/1206i82/wge70b81qyssm96rmrytze45m5i82);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">21</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/300-berry-street-unit-1009-san-francisco-ca-94158-CBR51632374">
#
#
#                 $710,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>1</strong> bed
#           </div>
#  <div class="property-baths">
#  <strong>1</strong> bath
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>597</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="300 Berry Street Unit 1009">
#                 300 Berry Street Unit 1009
#              </div>
#  <div class="property-city">
#              San Francisco CA 94158
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Coldwell Banker San Francisco Pacific Heights
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>
#  <div class="infinite-item property-card clearfix property-card-BHG50168609" data-brand-cd="BHG" data-id="BHG50168609" data-latitude="37.717087" data-link="/property/80-jennings-ct-san-francisco-ca-94124-BHG50168609" data-listing-id="" data-longitude="-122.396932" data-mls="ML81815654" data-source-id="FBD03321-431A-4A09-B605-D904B52FA36D" data-zip="94124">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://dev.virtualearth.net/REST/v1/Imagery/Map/Aerial/37.717087,-122.396932/18?key=Aifo-Q0bU-2xqFafu5AzBNi5fz59f5ufmjxeulcOJc1DddNIqLLW5Sozv3EQ8dhn&amp;mapSize=800,600);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">1</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/80-jennings-ct-san-francisco-ca-94124-BHG50168609">
#
#
#                 $808,888
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,212</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="80 Jennings Ct">
#                 80 Jennings Ct
#              </div>
#  <div class="property-city">
#              San Francisco CA 94124
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Better Homes and Gardens Real Estate J.F. Finnegan Realtors
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>
#  <div class="infinite-item property-card clearfix property-card-REN013953303" data-brand-cd="REN" data-id="REN013953303" data-latitude="37.7399" data-link="/property/116-laidley-street-san-francisco-ca-94131-REN013953303" data-listing-id="" data-longitude="-122.431" data-mls="507952" data-source-id="3yd-SFMLSCA-507952" data-zip="94131">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www.century21.com/listhub/photo/maxxmax/photos.listhub.net/SFMLSCA/507952/1?lm=20201016T000042);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">36</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/116-laidley-street-san-francisco-ca-94131-REN013953303">
#
#
#                 $2,895,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="116 Laidley Street">
#                 116 Laidley Street
#              </div>
#  <div class="property-city">
#              San Francisco CA 94131
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Compass
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>
#  <div class="infinite-item property-card clearfix property-card-REN013953297" data-brand-cd="REN" data-id="REN013953297" data-latitude="37.7678" data-link="/property/169-alpine-terrace-san-francisco-ca-94117-REN013953297" data-listing-id="" data-longitude="-122.437" data-mls="508157" data-source-id="3yd-SFMLSCA-508157" data-zip="94117">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www.century21.com/listhub/photo/maxxmax/photos.listhub.net/SFMLSCA/508157/1?lm=20201015T190934);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">80</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/169-alpine-terrace-san-francisco-ca-94117-REN013953297">
#
#
#                 $2,195,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,930</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="169 Alpine Terrace">
#                 169 Alpine Terrace
#              </div>
#  <div class="property-city">
#              San Francisco CA 94117
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Berkshire Hathaway Franciscan Properties
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>
#  <div class="infinite-item property-card clearfix property-card-REN013953309" data-brand-cd="REN" data-id="REN013953309" data-latitude="37.7616" data-link="/property/1212-19th-street-san-francisco-ca-94107-REN013953309" data-listing-id="" data-longitude="-122.395" data-mls="508262" data-source-id="3yd-SFMLSCA-508262" data-zip="94107">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www.century21.com/listhub/photo/maxxmax/photos.listhub.net/SFMLSCA/508262/1?lm=20201015T230934);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">26</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1212-19th-street-san-francisco-ca-94107-REN013953309">
#
#
#                 $1,800,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,740</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1212 19th Street">
#                 1212 19th Street
#              </div>
#  <div class="property-city">
#              San Francisco CA 94107
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Compass
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>
#  <div class="infinite-item property-card clearfix property-card-REN013970883" data-brand-cd="REN" data-id="REN013970883" data-latitude="37.762465" data-link="/property/514-church-street-san-francisco-ca-94114-REN013970883" data-listing-id="" data-longitude="-122.428598" data-mls="508281" data-source-id="3yd-SFMLSCA-508281" data-zip="94114">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www.century21.com/listhub/photo/maxxmax/photos.listhub.net/SFMLSCA/508281/1?lm=20201016T211436);">
#  <div class="property-image-flag open-house">Open House</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">46</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/514-church-street-san-francisco-ca-94114-REN013970883">
#
#
#                 $1,595,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>1</strong> bath
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,675</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="514 Church Street">
#                 514 Church Street
#              </div>
#  <div class="property-city">
#              San Francisco CA 94114
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Compass
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>
#  <div class="infinite-item property-card clearfix property-card-REN013953296" data-brand-cd="REN" data-id="REN013953296" data-latitude="37.7302" data-link="/property/106-aptos-avenue-san-francisco-ca-94127-REN013953296" data-listing-id="" data-longitude="-122.467" data-mls="508218" data-source-id="3yd-SFMLSCA-508218" data-zip="94127">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www.century21.com/listhub/photo/maxxmax/photos.listhub.net/SFMLSCA/508218/1?lm=20201015T190913);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">63</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/106-aptos-avenue-san-francisco-ca-94127-REN013953296">
#
#
#                 $1,575,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>2,148</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="106 Aptos Avenue">
#                 106 Aptos Avenue
#              </div>
#  <div class="property-city">
#              San Francisco CA 94127
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Berkshire Hathaway Franciscan Properties
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>
#  <div class="infinite-item property-card clearfix property-card-REN013953308" data-brand-cd="REN" data-id="REN013953308" data-latitude="37.7751" data-link="/property/1776-grove-street-san-francisco-ca-94117-REN013953308" data-listing-id="" data-longitude="-122.446" data-mls="508141" data-source-id="3yd-SFMLSCA-508141" data-zip="94117">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www.century21.com/listhub/photo/maxxmax/photos.listhub.net/SFMLSCA/508141/1?lm=20201016T000037);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">65</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1776-grove-street-san-francisco-ca-94117-REN013953308">
#
#
#                 $1,550,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,660</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1776 Grove Street">
#                 1776 Grove Street
#              </div>
#  <div class="property-city">
#              San Francisco CA 94117
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Compass
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>
#  <div class="infinite-item property-card clearfix property-card-REN013970879" data-brand-cd="REN" data-id="REN013970879" data-latitude="37.78723" data-link="/property/3055-california-street-san-francisco-ca-94115-REN013970879" data-listing-id="" data-longitude="-122.44456" data-mls="508156" data-source-id="3yd-SFMLSCA-508156" data-zip="94115">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www.century21.com/listhub/photo/maxxmax/photos.listhub.net/SFMLSCA/508156/1?lm=20201016T211429);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">78</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/3055-california-street-san-francisco-ca-94115-REN013970879">
#
#
#                 $1,230,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,215</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="3055 California Street">
#                 3055 California Street
#              </div>
#  <div class="property-city">
#              San Francisco CA 94115
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Compass
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>
#  </div>]
